# %%
from google.colab import drive
ROOT = '/content/drive'
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os
import sys
from os.path import join 
repo_dir = '/content/drive/MyDrive/gong-metaphor-detection'

# %%
# pip install requirements (takes a while)
#!cd drive/MyDrive/Repos/gong-metaphor-detection/; pip install -r requirements.txt

# %%
# !pip install 'transformers==3.5.1'

# %%
# !pip install torch==1.4.0

# %%
# !pip install scikit-learn

# %% [markdown]
# # ************ MOH-X ************

# %%
# !cd drive/MyDrive/Repos/gong-metaphor-detection/; python3 run_metaphor_detection.py \
--data_dir data/MOH_X \
--model_type roberta \
--model_name_or_path roberta-large \
--output_dir output/MOH_X/modeltest/ \
--dataset moh_x \
--max_seq_length 256 \
--do_train \
--evaluate_during_training \
--do_lower_case \
--per_gpu_train_batch_size 6 \
--per_gpu_eval_batch_size 18 \
--num_train_epochs 5.0 \
--warmup_steps 500 \
--learning_rate 2e-5 \
--logging_steps 300 \
--overwrite_output_dir \
--overwrite_cache \

# %%
# !cd drive/MyDrive/Repos/gong-metaphor-detection/; python3 run_metaphor_detection.py \
--data_dir data/MOH_X \
--model_type roberta \
--model_name_or_path roberta-large \
--output_dir output/MOH_X/modeltest/ \
--dataset moh_x \
--max_seq_length 256 \
--do_predict \
--do_lower_case \
--overwrite_cache

# %% [markdown]
# # Performance metrics on mohx test data - NO POS
# 03/15/2022 19:16:24 - INFO - __main__ -   ***** Eval results *****
#
# 03/15/2022 19:16:24 - INFO - __main__ -     accuracy = 0.7037037037037037
#
# 03/15/2022 19:16:24 - INFO - __main__ -     f1 = 0.7473684210526317
#
# 03/15/2022 19:16:24 - INFO - __main__ -     loss = 0.0
#
# 03/15/2022 19:16:24 - INFO - __main__ -     precision = 0.6574074074074074
#
# 03/15/2022 19:16:24 - INFO - __main__ -     recall = 0.8658536585365854
#
# 03/15/2022 19:16:24 - INFO - __main__ -   Saving predictions to output/MOH_X/modeltest/test_labels.txt

# %% [markdown]
# # Performance metrics on mohx test data - WITH POS
#
# 03/15/2022 17:57:25 - INFO - __main__ -   ***** Eval results *****
#
# 03/15/2022 17:57:25 - INFO - __main__ -     accuracy = 0.7469135802469136
#
# 03/15/2022 17:57:25 - INFO - __main__ -     f1 = 0.7980295566502463
#
# 03/15/2022 17:57:25 - INFO - __main__ -     loss = 0.0
#
# 03/15/2022 17:57:25 - INFO - __main__ -     precision = 0.7043478260869566
#
# 03/15/2022 17:57:25 - INFO - __main__ -     recall = 0.9204545454545454
#
# 03/15/2022 17:57:25 - INFO - __main__ -   Saving predictions to output/MOH_X/modeltest/test_labels.txt

# %% [markdown]
# # ************ TroFI ************

# %%
# !cd drive/MyDrive/Repos/gong-metaphor-detection/; python3 run_metaphor_detection.py \
--data_dir data/Trofi \
--model_type roberta \
--model_name_or_path roberta-large \
--output_dir output/Trofi/modeltest/ \
--dataset trofi \
--max_seq_length 256 \
--do_train \
--evaluate_during_training \
--do_lower_case \
--per_gpu_train_batch_size 6 \
--per_gpu_eval_batch_size 18 \
--num_train_epochs 5.0 \
--warmup_steps 500 \
--learning_rate 2e-5 \
--logging_steps 500 \
--overwrite_output_dir \
--overwrite_cache

# %%
# !cd drive/MyDrive/Repos/gong-metaphor-detection/; python3 run_metaphor_detection.py \
--data_dir data/Trofi \
--model_type roberta \
--model_name_or_path roberta-large \
--output_dir output/Trofi/modeltest/ \
--dataset trofi \
--max_seq_length 256 \
--do_predict \
--do_lower_case \
--overwrite_cache

# %% [markdown]
# # Performance metrics on trofi test data - NO POS
#
# 03/15/2022 20:51:12 - INFO - __main__ -     accuracy = 0.6491978609625668
#
# 03/15/2022 20:51:12 - INFO - __main__ -     f1 = 0.6934579439252336
#
# 03/15/2022 20:51:12 - INFO - __main__ -     loss = 0.0
#
# 03/15/2022 20:51:12 - INFO - __main__ -     precision = 0.5621212121212121
#
# 03/15/2022 20:51:12 - INFO - __main__ -     recall = 0.9048780487804878
#
# 03/15/2022 20:51:12 - INFO - __main__ -   Saving predictions to output/Trofi/modeltest/test_labels.txt

# %% [markdown]
# # Performance metrics on trofi test data - WITH POS
#
# 03/15/2022 19:07:42 - INFO - __main__ -   ***** Eval results *****
#
# 03/15/2022 19:07:42 - INFO - __main__ -     accuracy = 0.6491978609625668
#
# 03/15/2022 19:07:42 - INFO - __main__ -     f1 = 0.6821705426356589
#
# 03/15/2022 19:07:42 - INFO - __main__ -     loss = 0.0
#
# 03/15/2022 19:07:42 - INFO - __main__ -     precision = 0.5659163987138264
#
# 03/15/2022 19:07:42 - INFO - __main__ -     recall = 0.8585365853658536
#
# 03/15/2022 19:07:42 - INFO - __main__ -   Saving predictions to output/Trofi/modeltest/test_labels.txt
